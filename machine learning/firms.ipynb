# %%
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=4 "https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global" --header "Authorization: Bearer 53D9FEBC-F293-11E9-AFC1-F32CA14C1506" -P ./data
# !wget -e robots=off -m -np -R .html,.tmp -nH --cut-dirs=4 "https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global" --header "Authorization: Bearer 53D9FEBC-F293-11E9-AFC1-F32CA14C1506" -P ./data
# Out:
# --2019-10-19 17:16:37--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global
# Resolving nrt3.modaps.eosdis.nasa.gov (nrt3.modaps.eosdis.nasa.gov)... 198.118.194.30, 2001:4d0:241a:40c0::30
# Connecting to nrt3.modaps.eosdis.nasa.gov (nrt3.modaps.eosdis.nasa.gov)|198.118.194.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12004 (12K) [text/html]
# Saving to: ‘./data/FIRMS/c6/Global’
#
# FIRMS/c6/Global     100%[===================>]  11.72K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2019-10-19 17:16:37 (290 MB/s) - ‘./data/FIRMS/c6/Global’ saved [12004/12004]
#
# --2019-10-19 17:16:37--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019232.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1541281 (1.5M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019232.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.47M  2.04MB/s    in 0.7s
#
# 2019-10-19 17:16:38 (2.04 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019232.txt’ saved [1541281/1541281]
#
# --2019-10-19 17:16:38--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019233.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1287587 (1.2M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019233.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.23M  --.-KB/s    in 0.009s
#
# 2019-10-19 17:16:38 (141 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019233.txt’ saved [1287587/1287587]
#
# --2019-10-19 17:16:38--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019234.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1309987 (1.2M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019234.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.25M  --.-KB/s    in 0.02s
#
# 2019-10-19 17:16:39 (61.3 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019234.txt’ saved [1309987/1309987]
#
# --2019-10-19 17:16:39--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019235.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1139514 (1.1M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019235.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.09M  --.-KB/s    in 0.01s
#
# 2019-10-19 17:16:39 (92.6 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019235.txt’ saved [1139514/1139514]
#
# --2019-10-19 17:16:39--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019236.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1253721 (1.2M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019236.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.20M  --.-KB/s    in 0.007s
#
# 2019-10-19 17:16:39 (174 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019236.txt’ saved [1253721/1253721]
#
# --2019-10-19 17:16:39--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019237.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 882563 (862K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019237.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 861.88K  --.-KB/s    in 0.005s
#
# 2019-10-19 17:16:39 (156 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019237.txt’ saved [882563/882563]
#
# --2019-10-19 17:16:39--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019238.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 960528 (938K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019238.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 938.02K  --.-KB/s    in 0.01s
#
# 2019-10-19 17:16:39 (92.4 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019238.txt’ saved [960528/960528]
#
# --2019-10-19 17:16:39--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019239.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1312759 (1.3M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019239.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.25M  --.-KB/s    in 0.01s
#
# 2019-10-19 17:16:40 (86.2 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019239.txt’ saved [1312759/1312759]
#
# --2019-10-19 17:16:40--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019240.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1141725 (1.1M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019240.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.09M  --.-KB/s    in 0.009s
#
# 2019-10-19 17:16:40 (123 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019240.txt’ saved [1141725/1141725]
#
# --2019-10-19 17:16:40--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019241.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1108941 (1.1M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019241.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.06M  --.-KB/s    in 0.01s
#
# 2019-10-19 17:16:40 (83.4 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019241.txt’ saved [1108941/1108941]
#
# --2019-10-19 17:16:40--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019242.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1097305 (1.0M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019242.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.05M  --.-KB/s    in 0.008s
#
# 2019-10-19 17:16:40 (123 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019242.txt’ saved [1097305/1097305]
#
# --2019-10-19 17:16:40--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019243.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 949945 (928K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019243.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 927.68K  --.-KB/s    in 0.006s
#
# 2019-10-19 17:16:40 (145 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019243.txt’ saved [949945/949945]
#
# --2019-10-19 17:16:40--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019244.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1083107 (1.0M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019244.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1.03M  --.-KB/s    in 0.01s
#
# 2019-10-19 17:16:40 (76.9 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019244.txt’ saved [1083107/1083107]
#
# --2019-10-19 17:16:40--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019245.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1108944 (1.1M) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019245.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>]   1
  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019283.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 737437 (720K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019283.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 720.15K  --.-KB/s    in 0.01s
#
# 2019-10-19 17:16:49 (67.0 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019283.txt’ saved [737437/737437]
#
# --2019-10-19 17:16:49--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019284.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 430380 (420K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019284.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 420.29K  --.-KB/s    in 0.002s
#
# 2019-10-19 17:16:49 (196 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019284.txt’ saved [430380/430380]
#
# --2019-10-19 17:16:49--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019285.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 649537 (634K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019285.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 634.31K  --.-KB/s    in 0.009s
#
# 2019-10-19 17:16:49 (72.5 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019285.txt’ saved [649537/649537]
#
# --2019-10-19 17:16:49--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019286.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 637170 (622K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019286.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 622.24K  --.-KB/s    in 0.005s
#
# 2019-10-19 17:16:49 (127 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019286.txt’ saved [637170/637170]
#
# --2019-10-19 17:16:49--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019287.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 653086 (638K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019287.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 637.78K  --.-KB/s    in 0.02s
#
# 2019-10-19 17:16:49 (31.3 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019287.txt’ saved [653086/653086]
#
# --2019-10-19 17:16:49--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019288.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 592124 (578K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019288.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 578.25K  --.-KB/s    in 0.009s
#
# 2019-10-19 17:16:50 (64.0 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019288.txt’ saved [592124/592124]
#
# --2019-10-19 17:16:50--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019289.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 462754 (452K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019289.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 451.91K  --.-KB/s    in 0.003s
#
# 2019-10-19 17:16:50 (127 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019289.txt’ saved [462754/462754]
#
# --2019-10-19 17:16:50--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019290.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 619162 (605K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019290.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 604.65K  --.-KB/s    in 0.004s
#
# 2019-10-19 17:16:50 (132 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019290.txt’ saved [619162/619162]
#
# --2019-10-19 17:16:50--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019291.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 587532 (574K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019291.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 573.76K  --.-KB/s    in 0.006s
#
# 2019-10-19 17:16:50 (88.9 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019291.txt’ saved [587532/587532]
#
# --2019-10-19 17:16:50--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019292.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 486102 (475K) [text/plain]
# Saving to: ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019292.txt’
#
# FIRMS/c6/Global/MOD 100%[===================>] 474.71K  --.-KB/s    in 0.003s
#
# 2019-10-19 17:16:50 (142 MB/s) - ‘./data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019292.txt’ saved [486102/486102]
#
# FINISHED --2019-10-19 17:16:50--
# Total wall clock time: 14s
# Downloaded: 62 files, 57M in 1.6s (35.6 MB/s)
# --2019-10-19 17:16:51--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global
# Resolving nrt3.modaps.eosdis.nasa.gov (nrt3.modaps.eosdis.nasa.gov)... 198.118.194.30, 2001:4d0:241a:40c0::30
# Connecting to nrt3.modaps.eosdis.nasa.gov (nrt3.modaps.eosdis.nasa.gov)|198.118.194.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12736 (12K) [text/html]
# Saving to: ‘./data/FIRMS/viirs/Global’
#
# FIRMS/viirs/Global  100%[===================>]  12.44K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2019-10-19 17:16:51 (256 MB/s) - ‘./data/FIRMS/viirs/Global’ saved [12736/12736]
#
# --2019-10-19 17:16:51--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019232.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7745199 (7.4M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019232.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   7.39M  6.49MB/s    in 1.1s
#
# 2019-10-19 17:16:52 (6.49 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019232.txt’ saved [7745199/7745199]
#
# --2019-10-19 17:16:52--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019233.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6505297 (6.2M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019233.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   6.20M  21.8MB/s    in 0.3s
#
# 2019-10-19 17:16:53 (21.8 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019233.txt’ saved [6505297/6505297]
#
# --2019-10-19 17:16:53--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019234.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5492175 (5.2M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019234.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   5
  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019281.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4105600 (3.9M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019281.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.92M  25.2MB/s    in 0.2s
#
# 2019-10-19 17:17:10 (25.2 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019281.txt’ saved [4105600/4105600]
#
# --2019-10-19 17:17:10--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019282.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4145488 (4.0M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019282.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.95M  26.3MB/s    in 0.2s
#
# 2019-10-19 17:17:10 (26.3 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019282.txt’ saved [4145488/4145488]
#
# --2019-10-19 17:17:10--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019283.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3954903 (3.8M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019283.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.77M  --.-KB/s    in 0.1s
#
# 2019-10-19 17:17:11 (25.6 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019283.txt’ saved [3954903/3954903]
#
# --2019-10-19 17:17:11--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019284.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3101983 (3.0M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019284.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   2.96M  --.-KB/s    in 0.02s
#
# 2019-10-19 17:17:11 (168 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019284.txt’ saved [3101983/3101983]
#
# --2019-10-19 17:17:11--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019285.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3252515 (3.1M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019285.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.10M  --.-KB/s    in 0.1s
#
# 2019-10-19 17:17:11 (21.7 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019285.txt’ saved [3252515/3252515]
#
# --2019-10-19 17:17:11--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019286.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3759245 (3.6M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019286.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.58M  --.-KB/s    in 0.1s
#
# 2019-10-19 17:17:12 (24.6 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019286.txt’ saved [3759245/3759245]
#
# --2019-10-19 17:17:12--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019287.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3909944 (3.7M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019287.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.73M  --.-KB/s    in 0.1s
#
# 2019-10-19 17:17:12 (25.5 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019287.txt’ saved [3909944/3909944]
#
# --2019-10-19 17:17:12--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019288.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3181750 (3.0M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019288.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.03M  --.-KB/s    in 0.1s
#
# 2019-10-19 17:17:12 (21.3 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019288.txt’ saved [3181750/3181750]
#
# --2019-10-19 17:17:12--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019289.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2984232 (2.8M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019289.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   2.85M  --.-KB/s    in 0.02s
#
# 2019-10-19 17:17:12 (157 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019289.txt’ saved [2984232/2984232]
#
# --2019-10-19 17:17:12--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019290.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3122761 (3.0M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019290.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   2.98M  --.-KB/s    in 0.1s
#
# 2019-10-19 17:17:13 (21.0 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019290.txt’ saved [3122761/3122761]
#
# --2019-10-19 17:17:13--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019291.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3193596 (3.0M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019291.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   3.04M  --.-KB/s    in 0.1s
#
# 2019-10-19 17:17:13 (21.2 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019291.txt’ saved [3193596/3193596]
#
# --2019-10-19 17:17:13--  https://nrt3.modaps.eosdis.nasa.gov/api/v2/content/archives/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019292.txt
# Reusing existing connection to nrt3.modaps.eosdis.nasa.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2336264 (2.2M) [text/plain]
# Saving to: ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019292.txt’
#
# FIRMS/viirs/Global/ 100%[===================>]   2.23M  --.-KB/s    in 0.01s
#
# 2019-10-19 17:17:13 (163 MB/s) - ‘./data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019292.txt’ saved [2336264/2336264]
#
# FINISHED --2019-10-19 17:17:13--
# Total wall clock time: 23s
# Downloaded: 62 files, 311M in 12s (26.2 MB/s)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import cv2
from functions import *

# %%
for day in [232]:
    modis_df = pd.read_csv("data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019" + str(day) + ".txt")
    viirs_df = pd.read_csv("data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019" + str(day) + ".txt")
# Out:
#    latitude  longitude  brightness  scan  track    acq_date acq_time  \
# 0    38.295     27.066       305.4   1.1    1.1  2019-08-20    00:00
# 1    38.286     27.064       304.8   1.1    1.1  2019-08-20    00:00
# 2    38.261     26.957       308.1   1.1    1.1  2019-08-20    00:00
# 3    48.170     37.710       300.3   1.3    1.1  2019-08-20    00:00
# 4    38.249     27.057       315.7   1.1    1.1  2019-08-20    00:00
#
#   satellite  confidence version  bright_t31   frp daynight
# 0         A          63  6.0NRT       293.5   6.9        N
# 1         A          48  6.0NRT       293.7   6.1        N
# 2         A          74  6.0NRT       292.8   9.5        N
# 3         A          21  6.0NRT       289.9   6.5        N
# 4         A          92  6.0NRT       294.6  14.4        N

# %%
modis_df.head()
# Out:
#    latitude  longitude    acq_date acq_time  confidence   frp
# 0    38.295     27.066  2019-08-20    00:00          63   6.9
# 1    38.286     27.064  2019-08-20    00:00          48   6.1
# 2    38.261     26.957  2019-08-20    00:00          74   9.5
# 3    48.170     37.710  2019-08-20    00:00          21   6.5
# 4    38.249     27.057  2019-08-20    00:00          92  14.4

# %%
viirs_df.confidence.unique()
# Out:
# array(['nominal', 'low', 'high'], dtype=object)

# %%
viirs_df.head()
# Out:
#    latitude  longitude    acq_date acq_time  confidence  frp
# 0  56.63437  161.30266  2019-08-20    00:30          60  5.2
# 1  56.62982  161.29715  2019-08-20    00:30          60  5.7
# 2  58.96115  159.84595  2019-08-20    00:30          30  3.3
# 3  56.62749  161.30118  2019-08-20    00:30          60  4.8
# 4  52.82091 -169.94514  2019-08-20    00:30          60  4.7

# %%
viirs_df['confidence'] = viirs_df['confidence'].apply(lambda x: {"low": 30, "nominal": 60, "high": 90}[x])

# %%
viirs_df = viirs_df.drop(columns=['bright_ti4', 'scan', 'track', 'satellite', 'version', 'bright_ti5', 'daynight'])
modis_df = modis_df.drop(columns=['brightness', 'scan', 'track', 'satellite', 'version', 'bright_t31', 'daynight'])

# %%
df = pd.concat([viirs_df, modis_df])

len(df), len(viirs_df), len(modis_df)
# Out:
# (120035, 97595, 22440)

# %%
date_to_day = lambda x: (datetime.strptime(x['acq_date'] + " " + x['acq_time'], '%Y-%m-%d %H:%M') -
                         datetime(1970,1,1)).total_seconds() / (3600 * 24)

df['day'] = df.apply(date_to_day, axis=1)

# %%
df.head()
# Out:
#    latitude  longitude    acq_date acq_time  confidence  frp           day
# 0  56.63437  161.30266  2019-08-20    00:30          60  5.2  18128.020833
# 1  56.62982  161.29715  2019-08-20    00:30          60  5.7  18128.020833
# 2  58.96115  159.84595  2019-08-20    00:30          30  3.3  18128.020833
# 3  56.62749  161.30118  2019-08-20    00:30          60  4.8  18128.020833
# 4  52.82091 -169.94514  2019-08-20    00:30          60  4.7  18128.020833

# %%
for point in [23, 4567, 43232, 110323, 21342, 99999]:
    point_s = df.iloc[point]
    near_points = df[(point_s.latitude - 0.01 <= df.latitude) &
                     (df.latitude <= point_s.latitude + 0.01) &
                     (point_s.longitude - 0.01 <= df.longitude) &
                     (df.longitude <= point_s.longitude + 0.01) &
                     (point_s.day - 1 <= df.day) &
                     (df.day <= point_s.day + 1)]
    
    print(len(near_points))
# Out:
# 32
# 11
# 4
# 2
# 6
# 21

# %%
def get_df(days):
    df = None
    for day in days:
        modis_df = pd.read_csv("data/FIRMS/c6/Global/MODIS_C6_Global_MCD14DL_NRT_2019" + str(day) + ".txt")
        viirs_df = pd.read_csv("data/FIRMS/viirs/Global/VIIRS_I_Global_VNP14IMGTDL_NRT_2019" + str(day) + ".txt")
        viirs_df['confidence'] = viirs_df['confidence'].apply(lambda x: {"low": 30, "nominal": 60, "high": 90}[x])
        viirs_df = viirs_df.drop(columns=['bright_ti4', 'scan', 'track', 'satellite', 'version', 'bright_ti5', 'daynight'])
        modis_df = modis_df.drop(columns=['brightness', 'scan', 'track', 'satellite', 'version', 'bright_t31', 'daynight'])
        if df is None:
            df = pd.concat([viirs_df, modis_df])
        else:
            df = pd.concat([df, viirs_df, modis_df])
    
    print(len(df))
    
    date_to_day = lambda x: (datetime.strptime(x['acq_date'] + " " + x['acq_time'], '%Y-%m-%d %H:%M') -
                         datetime(1970,1,1)).total_seconds() / (3600 * 24)
    df['day'] = df.apply(date_to_day, axis=1)
    
    return df

# %%
def get_points(spacial_delta, temporal_delta, df):
    point_s = df.iloc[np.random.randint(0, len(df) - 1)]
    near_points = df[(point_s.latitude - spacial_delta <= df.latitude) &
                     (df.latitude <= point_s.latitude + spacial_delta) &
                     (point_s.longitude - spacial_delta <= df.longitude) &
                     (df.longitude <= point_s.longitude + spacial_delta) &
                     (point_s.day - temporal_delta <= df.day) &
                     (df.day <= point_s.day + temporal_delta)]
    return near_points

# %%
def get_map(points, s3_scenes):
    points.sort_values(by=['day'])
    date_time = datetime.strptime(points.iloc[0]['acq_date'] + " " + points.iloc[0]['acq_time'], '%Y-%m-%d %H:%M')
    lats = points["latitude"].values
    lons = points["longitude"].values
    
    coords = []
    coords.append([np.min(lats) - 0.001, np.min(lons) - 0.001])
    coords.append([np.max(lats) + 0.001, np.max(lons) + 0.001])
    
    b5 = get_image(coords, date_time, 5, s3_scenes)
    b3 = get_image(coords, date_time, 3, s3_scenes)
    b4 = get_image(coords, date_time, 4, s3_scenes)
    
    print(np.min(b3), np.average(b3), np.max(b3))
    print(np.min(b4), np.average(b4), np.max(b4))
    print(np.min(b5), np.average(b5), np.max(b5))
    
    false_col = np.stack(((b3 - np.min(b3)) / (np.max(b3) - np.min(b3)), 
                          (b4 - np.min(b4)) / (np.max(b4) - np.min(b4)), 
                          (b5 - np.min(b5)) / (np.max(b5) - np.min(b5))), axis=2)
    return coords, false_col

# %%
def coords_to_pos(coords, bounds, shape):
    x = (bounds[1][0] - coords[0]) / (bounds[1][0] - bounds[0][0]) * shape[0]
    y = (coords[1] - bounds[0][1]) / (bounds[1][1] - bounds[0][1]) * shape[1]
    return int(y), int(x)

# %%
s3_scenes = get_s3_scenes()

# %%
df = get_df(list(range(290, 293)))
# Out:
# 133527

# %%
df.head()
# Out:
#    latitude  longitude    acq_date acq_time  confidence   frp         day
# 0  66.28590   78.74406  2019-10-17    00:54          60  42.7  18186.0375
# 1  66.27876   78.75006  2019-10-17    00:54          60  42.9  18186.0375
# 2  67.80300   72.52676  2019-10-17    00:54          60   2.8  18186.0375
# 3  67.80223   72.51971  2019-10-17    00:54          60   3.5  18186.0375
# 4  68.41327   83.63153  2019-10-17    00:54          60  26.4  18186.0375

# %%
points = get_points(0.09, 10, df)
points
# Out:
# 18295 -15.70268   22.89571  2019-10-19    11:36          30   7.2
# 18299 -15.69829   22.89515  2019-10-19    11:36          60   7.2
# 18301 -15.70259   22.89805  2019-10-19    11:36          90   9.6
# 18302 -15.69819   22.89750  2019-10-19    11:36          60   9.6
#
#                 day
# 20762  18186.508333
# 20768  18186.508333
# 20770  18186.508333
# 20775  18186.508333
# 21208  18186.508333
# 21211  18186.508333
# 21212  18186.508333
# 20724  18187.495833
# 20725  18187.495833
# 20726  18187.495833
# 20727  18187.495833
# 20728  18187.495833
# 20729  18187.495833
# 20752  18187.495833
# 20753  18187.495833
# 20756  18187.495833
# 20757  18187.495833
# 20758  18187.495833
# 20760  18187.495833
# 20761  18187.495833
# 20762  18187.495833
# 20763  18187.495833
# 20764  18187.495833
# 20765  18187.495833
# 20766  18187.495833
# 20767  18187.495833
# 21221  18187.495833
# 21222  18187.495833
# 21223  18187.495833
# 21226  18187.495833
# 21227  18187.495833
# 3791   18187.388889
# 3793   18187.388889
# 5387   18187.506944
# 5388   18187.506944
# 5397   18187.506944
# 17906  18188.483333
# 17911  18188.483333
# 18198  18188.483333
# 18199  18188.483333
# 18200  18188.483333
# 18203  18188.483333
# 18240  18188.483333
# 18263  18188.483333
# 18282  18188.483333
# 18294  18188.483333
# 18295  18188.483333
# 18299  18188.483333
# 18301  18188.483333
# 18302  18188.483333

# %%
bounds, false_col_map = get_map(points, s3_scenes)
# Out:
# 1
#
#  EntityId: LC08_L1TP_175071_20190930_20191017_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_175071_20190930_20191017_01_T1_B5.TIF
# [22.856329999999996, 22.99611, -15.786, -15.624620000000002]
# 1
#
#  EntityId: LC08_L1TP_175071_20190930_20191017_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_175071_20190930_20191017_01_T1_B3.TIF
# [22.856329999999996, 22.99611, -15.786, -15.624620000000002]
# 1
#
#  EntityId: LC08_L1TP_175071_20190930_20191017_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_175071_20190930_20191017_01_T1_B4.TIF
# [22.856329999999996, 22.99611, -15.786, -15.624620000000002]
# 9447 11031.791725921137 15560
# 8926 11570.740387167012 17576
# 8971 16097.786649882624 21996

# %%
plt.imshow(false_col_map)
plt.show()

# %%
print(bounds)

days = list(range(18180, 18200))

for day in days:
    fil_points = points[(day <= points.day) & (points.day < day + 1)]
    if len(fil_points) == 0:
        continue
    false_col_map_copy = false_col_map.copy()
    for p in fil_points.index:
        overlay = np.zeros(false_col_map_copy.shape, false_col_map.dtype)
        cv2.circle(overlay, coords_to_pos((fil_points.loc[p].latitude, fil_points.loc[p].longitude),
                                                     bounds, false_col_map.shape), 12, (1, 0, 0), -1)
#         cv2.drawMarker(false_col_map_copy, coords_to_pos((fil_points.loc[p].latitude, fil_points.loc[p].longitude),
#                                                     bounds, false_col_map.shape), (0, 1, 0), markerSize = 5, thickness = 3)
        alpha = fil_points.loc[p].confidence / 100    
        cv2.addWeighted(overlay, alpha, false_col_map_copy, 1, 0, false_col_map_copy)
        false_col_map_copy = np.clip(false_col_map_copy, 0, 1)
    plt.imshow(false_col_map_copy)
    plt.show()
# Out:
# [[-15.786, 22.856329999999996], [-15.624620000000002, 22.99611]]

# %%
class SeriesGenerator(object):
    def __init__(self):
        self.s3_scenes = get_s3_scenes()
        self.df = get_df(list(range(232, 293)))
        
    def get_series(self):
        points = []
        while len(points) < 10:
            points = get_points(0.09, 10, self.df)
        bounds, false_col_map = get_map(points, self.s3_scenes)
        
        days = list(range(18100, 18200))
        
        masks = []

        for day in days:
            fil_points = points[(day <= points.day) & (points.day < day + 1)]
            if len(fil_points) == 0:
                continue
            mask = np.zeros(false_col_map.shape[:2], false_col_map.dtype)
            for p in fil_points.index:
                overlay = np.zeros(mask.shape, mask.dtype)
                cv2.circle(overlay, coords_to_pos((fil_points.loc[p].latitude, fil_points.loc[p].longitude),
                                                             bounds, false_col_map.shape), 12, 1, -1)
                alpha = fil_points.loc[p].confidence / 100
                cv2.addWeighted(overlay, alpha, mask, 1, 0, mask)
                false_col_map_copy = np.clip(mask, 0, 1)
            masks.append(mask)
        return false_col_map, masks

# %%
series_gen = SeriesGenerator()
# Out:
# 4977788

# %%
false_col_map, masks = series_gen.get_series()
# Out:
# 2
#
#  EntityId: LC08_L1TP_226074_20190530_20190605_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_226074_20190530_20190605_01_T1_B5.TIF
#
#  EntityId: LC08_L1TP_227074_20190708_20190719_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_227074_20190708_20190719_01_T1_B5.TIF
# [-57.759859999999996, -57.57856, -20.744000000000003, -20.56495]
# 2
#
#  EntityId: LC08_L1TP_226074_20190530_20190605_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_226074_20190530_20190605_01_T1_B3.TIF
#
#  EntityId: LC08_L1TP_227074_20190708_20190719_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_227074_20190708_20190719_01_T1_B3.TIF
# [-57.759859999999996, -57.57856, -20.744000000000003, -20.56495]
# 2
#
#  EntityId: LC08_L1TP_226074_20190530_20190605_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_226074_20190530_20190605_01_T1_B4.TIF
#
#  EntityId: LC08_L1TP_227074_20190708_20190719_01_T1
#
#  Checking content:
#
#   Downloading: LC08_L1TP_227074_20190708_20190719_01_T1_B4.TIF
# [-57.759859999999996, -57.57856, -20.744000000000003, -20.56495]
# 6234 7259.249058719859 8856
# 5678 6746.244519212796 9114
# 4785 11754.070609968952 18760
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-49-afd6e1939db7> in <module>
# ----> 1 false_col_map, masks = series_gen.get_series()
#
# <ipython-input-46-818e229281bb> in get_series(self)
#      24                                                              bounds, false_col_map.shape), 12, 1, -1)
#      25                 alpha = fil_points.loc[p].confidence / 100
# ---> 26                 cv2.addWeighted(overlay, alpha, false_col_map_copy, 1, 0, mask)
#      27                 false_col_map_copy = np.clip(mask, 0, 1)
#      28             masks.append(mask)
#
# UnboundLocalError: local variable 'false_col_map_copy' referenced before assignment

# %%
plt.imshow(false_col_map_copy)
plt.show()

for mask in masks:
    plt.imshow(mask)
    plt.show()
